# %%
def reverse_complement(dna):
    seq = ''
    for i in dna:
        if i == 'A':
            sea = seq + 'T'
        elif i == 'T':
            seq = seq + 'A'
        elif i == 'C':
            seq = seq + 'G'
        elif i == 'G':
            seq = seq + 'C'
    return seq[::-1]

dna = '...'
reverse_complement(dna)
# Out:
# '...'

# %%
def revcomplement(dna):
    dna = '...'

    print ('original sequence is', dna)
    
    for i in dna:
        if i == 'A':
            dna = dna.replace('A', 'T')
        elif i == 'T':
            dna = dna.replace('T', 'A')
        elif i == 'C':
            dna = dna.replace('C', 'G')
        elif i == 'G':
            dna = dna.replace('G', 'C')
    return dna



revcomplement(dna)
